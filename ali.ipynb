# %%
afdafdd""
# Out:
#   Cell In[1], line 1
#     afdafdd""
#            ^
# SyntaxError: invalid syntax

# %%
print("asdfa")
# Out:
# asdfa

# %%
read("asfd")
# Out:
# Now we are able to read data from datasource asfd the data which we need!
# 'fetch data of asfd'

# %%
print("jkn")
# Out:
# jkn

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris

# --- Train a scikit-learn model ---
X, y = load_iris(return_X_y=True)
sklearn_model = RandomForestClassifier().fit(X, y)

my_custom_tags = {
    "tag": 0.98,
    "model_type": "RandomForest"
}
start_run("new_run")
register_model(sklearn_model, "MyModel", tags=my_custom_tags)
end_run()
# Out:
# --- [SDK] Finding notebook path to set experiment...
# --- [SDK] Automatically setting experiment to: 'ali.ipynb' ---
# --- [SDK] Starting run: new_run (ID: b40094ff8edc43d98ea5b54b1c4e20f4) ---
# Attempting to register model MyModel.
# Detected scikit-learn model.
# Registered model 'MyModel' already exists. Creating a new version of this model...
# 2025/11/12 17:06:50 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: MyModel, version 4
# --- [SDK] Manually ending run: new_run ---
# Created version '4' of model 'MyModel'.

# %%
with start_run("My-Experiment-1"):
    register_model(sklearn_model, "MyModel", tags=my_custom_tags)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 with start_run("My-Experiment-1"):
#       2     register_model(sklearn_model, "MyModel", tags=my_custom_tags)
#
# NameError: name 'start_run' is not defined
