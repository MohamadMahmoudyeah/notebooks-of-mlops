# %%
# The user's notebook code:

# Example 1: Load the "Production" version of a model
try:
    prod_model = load_model(model_name="MyFirstModel", version=13)
    
except Exception as e:
    print(f"Could not load production model: {e}")
# Out:
# Could not load production model: name 'load_model' is not defined
