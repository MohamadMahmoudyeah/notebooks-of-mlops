# %%
# The user's notebook code:

# Example 1: Load the "Production" version of a model
try:
    prod_model = sdk.load_model(model_name="my-cool-classifier")
    
    # 'prod_model' is a pyfunc model, so it has .predict()
    predictions = prod_model.predict(some_new_data)
    
except Exception as e:
    print(f"Could not load production model: {e}")


# Example 2: Load a specific version for testing
try:
    test_model_v3 = sdk.load_model(model_name="my-cool-classifier", version=3)
    
    # Use it for prediction
    v3_predictions = test_model_v3.predict(test_data)

except Exception as e:
    print(f"Could not load version 3: {e}")


# Example 3: Load the "Staging" version
try:
    staging_model = sdk.load_model(model_name="my-cool-classifier", stage="Staging")
    
    # Use it for prediction
    staging_predictions = staging_model.predict(test_data)

except Exception as e:
    print(f"Could not load staging model: {e}")
