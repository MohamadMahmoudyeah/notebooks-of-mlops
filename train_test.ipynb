# %%
""" This is a simple LinearRegression model training code for
testing our mlflow server, this code was generated by AI. """

import mlflow
import pandas as pd
from sqlalchemy import create_engine
from sklearn.linear_model import LinearRegression

MLFLOW_TRACKING_URI = "http://127.0.0.1:5001"
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

EXPERIMENT_NAME = "MyMLOpsProject_V5"
ARTIFACT_PATH = "file:///home/mohamad/Desktop/mlops_platform/my_mlflow_data"

try:
    experiment_id = mlflow.create_experiment(
        name=EXPERIMENT_NAME, 
        artifact_location=ARTIFACT_PATH
    )
except mlflow.exceptions.MlflowException as e:
    experiment_id = mlflow.get_experiment_by_name(EXPERIMENT_NAME).experiment_id

mlflow.set_experiment(experiment_id=experiment_id)

DB_URL = "postgresql://mlflow_user:mlflow_pass@localhost:5432/app_data"

def get_data_from_db():
    print(f"Connecting to DB at {DB_URL}...")
    try:
        engine = create_engine(DB_URL)
        query = "SELECT feature_1, feature_2, target FROM model_data"
        df = pd.read_sql(query, engine)
        print("Data loaded successfully from Postgres:")
        print(df.head())
        return df
    except Exception as e:
        print(f"Error connecting to DB or fetching data: {e}")
        return None

def train_model(df):
    print("Starting model training...")

    with mlflow.start_run() as run:
        X = df[['feature_1', 'feature_2']]
        y = df['target']

        n_estimators = 10
        mlflow.log_param("n_estimators", n_estimators)

        model = LinearRegression()
        model.fit(X, y)

        score = model.score(X, y)
        print(f"Model Score (R2): {score}")

        mlflow.log_metric("r2_score", score)

        mlflow.sklearn.log_model(
            sk_model=model,
            artifact_path="model_artifacts",
            registered_model_name="MyFirstModel"
        )

        print(f"Model logged successfully with run ID: {run.info.run_id}")
        print(f"View this run in MLflow UI: {MLFLOW_TRACKING_URI}/#/experiments/{run.info.experiment_id}/runs/{run.info.run_id}")

data = get_data_from_db()
if data is not None:
    train_model(data)
# Out:
# Connecting to DB at postgresql://mlflow_user:mlflow_pass@localhost:5432/app_data...
# Data loaded successfully from Postgres:
#    feature_1  feature_2  target
# 0        1.1        2.2     3.3
# 1        2.1        3.2     5.3
# 2        3.1        4.2     7.3
# 3        4.1        5.2     9.3
# Starting model training...
# 2025/11/05 11:57:56 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Model Score (R2): 1.0
# 🏃 View run unleashed-crane-891 at: http://127.0.0.1:5001/#/experiments/11/runs/b2bf2552b4da4b27ba58a545d0227d33
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/11
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[42], line 69
#      67 data = get_data_from_db()
#      68 if data is not None:
# ---> 69     train_model(data)
#
# Cell In[42], line 58, in train_model(df)
#      54 print(f"Model Score (R2): {score}")
#      56 mlflow.log_metric("r2_score", score)
# ---> 58 mlflow.sklearn.log_model(
#      59     sk_model=model,
#      60     artifact_path="model_artifacts",
#      61     registered_model_name="MyFirstModel"
#      62 )
#      64 print(f"Model logged successfully with run ID: {run.info.run_id}")
#      65 print(f"View this run in MLflow UI: {MLFLOW_TRACKING_URI}/#/experiments/{run.info.experiment_id}/runs/{run.info.run_id}")
#
# File ~/miniconda3/envs/datalayer/lib/python3.11/site-packages/mlflow/sklearn/__init__.py:426, in log_model(sk_model, artifact_path, conda_env, code_paths, serialization_format, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, pyfunc_predict_fn, metadata, params, tags, model_type, step, model_id, name)
#     334 @format_docstring(LOG_MODEL_PARAM_DOCS.format(package_name="scikit-learn"))
#     335 def log_model(
#     336     sk_model,
#    (...)    355     name: str | None = None,
#     356 ):
#     357     """
#     358     Log a scikit-learn model as an MLflow artifact for the current run. Produces an MLflow Model
#     359     containing the following flavors:
#    (...)    424
#     425     """
# --> 426     return Model.log(
#     427         artifact_path=artifact_path,
#     428         name=name,
#     429         flavor=mlflow.sklearn,
#     430         sk_model=sk_model,
#     431         conda_env=conda_env,
#     432         code_paths=code_paths,
#     433         serialization_format=serialization_format,
#     434         registered_model_name=registered_model_name,
#     435         signature=signature,
#     436         input_example=input_example,
#     437         await_registration_for=await_registration_for,
#     438         pip_requirements=pip_requirements,
#     439         extra_pip_requirements=extra_pip_requirements,
#     440         pyfunc_predict_fn=pyfunc_predict_fn,
#     441         metadata=metadata,
#     442         params=params,
#     443         tags=tags,
#     444         model_type=model_type,
#     445         step=step,
#     446         model_id=model_id,
#     447     )
#
# File ~/miniconda3/envs/datalayer/lib/python3.11/site-packages/mlflow/models/model.py:1170, in Model.log(cls, artifact_path, flavor, registered_model_name, await_registration_for, metadata, run_id, resources, auth_policy, prompts, name, model_type, params, tags, step, model_id, **kwargs)
#    1168 if flavor_name is None:
#    1169     flavor_name = flavor.__name__ if hasattr(flavor, "__name__") else "custom"
# -> 1170 model = _create_logged_model(
#    1171     # TODO: Update model name
#    1172     name=name,
#    1173     source_run_id=run_id,
#    1174     model_type=model_type,
#    1175     params={key: str(value) for key, value in params.items()},
#    1176     tags={key: str(value) for key, value in tags.items()}
#    1177     if tags is not None
#    1178     else None,
#    1179     flavor=flavor_name,
#    1180 )
#    1181 _last_logged_model_id.set(model.model_id)
#    1182 if (
#    1183     MLFLOW_PRINT_MODEL_URLS_ON_CREATION.get()
#    1184     and is_databricks_uri(tracking_uri)
#    1185     and (workspace_url := get_workspace_url())
#    1186 ):
#
# File ~/miniconda3/envs/datalayer/lib/python3.11/site-packages/mlflow/tracking/fluent.py:2323, in _create_logged_model(name, source_run_id, tags, params, model_type, experiment_id, flavor)
#    2319     experiment_id = _get_experiment_id() or (
#    2320         get_run(source_run_id).info.experiment_id if source_run_id else None
#    2321     )
#    2322 resolved_tags = context_registry.resolve_tags(tags)
# -> 2323 return MlflowClient()._create_logged_model(
#    2324     experiment_id=experiment_id,
#    2325     name=name,
#    2326     source_run_id=source_run_id,
#    2327     tags=resolved_tags,
#    2328     params=params,
#    2329     model_type=model_type,
#    2330     flavor=flavor,
#    2331 )
#
# File ~/miniconda3/envs/datalayer/lib/python3.11/site-packages/mlflow/tracking/client.py:5492, in MlflowClient._create_logged_model(self, experiment_id, name, source_run_id, tags, params, model_type, flavor)
#    5482 def _create_logged_model(
#    5483     self,
#    5484     experiment_id: str,
#    (...)   5490     flavor: str | None = None,
#    5491 ) -> LoggedModel:
# -> 5492     return self._tracking_client.create_logged_model(
#    5493         experiment_id, name, source_run_id, tags, params, model_type, flavor
#    5494     )
#
# File ~/miniconda3/envs/datalayer/lib/python3.11/site-packages/mlflow/telemetry/track.py:30, in record_usage_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      28 start_time = time.time()
#      29 try:
# ---> 30     result = func(*args, **kwargs)
#      31     return result  # noqa: RET504
#      32 except Exception:
#
# File ~/miniconda3/envs/datalayer/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py:870, in TrackingServiceClient.create_logged_model(self, experiment_id, name, source_run_id, tags, params, model_type, flavor)
#     857 @record_usage_event(CreateLoggedModelEvent)
#     858 def create_logged_model(
#     859     self,
#    (...)    868     flavor: str | None = None,
#     869 ) -> LoggedModel:
# --> 870     return self.store.create_logged_model(
#     871         experiment_id=experiment_id,
#     872         name=name,
#     873         source_run_id=source_run_id,
#     874         tags=[LoggedModelTag(str(key), str(value)) for key, value in tags.items()]
#     875         if tags is not None
#     876         else tags,
#     877         params=[LoggedModelParameter(str(key), str(value)) for key, value in params.items()]
#     878         if params is not None
#     879         else params,
#     880         model_type=model_type,
#     881     )
#
# File ~/miniconda3/envs/datalayer/lib/python3.11/site-packages/mlflow/store/tracking/rest_store.py:894, in RestStore.create_logged_model(self, experiment_id, name, source_run_id, tags, params, model_type)
#     881     remaining_params = params[initial_batch_size:]
#     883 req_body = message_to_json(
#     884     CreateLoggedModel(
#     885         experiment_id=experiment_id,
#    (...)    891     )
#     892 )
# --> 894 response_proto = self._call_endpoint(CreateLoggedModel, req_body)
#     895 model = LoggedModel.from_proto(response_proto.model)
#     897 # Log remaining params if there are any
#
# File ~/miniconda3/envs/datalayer/lib/python3.11/site-packages/mlflow/store/tracking/rest_store.py:201, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds, response_proto)
#     199     endpoint, method = self._METHOD_TO_INFO[api]
#     200 response_proto = response_proto or api.Response()
# --> 201 return call_endpoint(
#     202     self.get_host_creds(),
#     203     endpoint,
#     204     method,
#     205     json_body,
#     206     response_proto,
#     207     retry_timeout_seconds=retry_timeout_seconds,
#     208 )
#
# File ~/miniconda3/envs/datalayer/lib/python3.11/site-packages/mlflow/utils/rest_utils.py:592, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     589     call_kwargs["json"] = json_body
#     590     response = http_request(**call_kwargs)
# --> 592 response = verify_rest_response(response, endpoint)
#     593 response_to_parse = response.text
#     594 try:
#
# File ~/miniconda3/envs/datalayer/lib/python3.11/site-packages/mlflow/utils/rest_utils.py:317, in verify_rest_response(response, endpoint)
#     312     else:
#     313         base_msg = (
#     314             f"API request to endpoint {endpoint} "
#     315             f"failed with error code {response.status_code} != 200"
#     316         )
# --> 317         raise MlflowException(
#     318             f"{base_msg}. Response body: '{response.text}'",
#     319             error_code=get_error_code(response.status_code),
#     320         )
#     322 # Skip validation for endpoints (e.g. DBFS file-download API) which may return a non-JSON
#     323 # response
#     324 if endpoint.startswith(_REST_API_PATH_PREFIX) and not _can_parse_as_json_object(response.text):
#
# MlflowException: API request to endpoint /api/2.0/mlflow/logged-models failed with error code 404 != 200. Response body: '<!doctype html>
# <html lang=en>
# <title>404 Not Found</title>
# <h1>Not Found</h1>
# <p>The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.</p>
# '

# %%
# !mlflow --version
# Out:
# mlflow, version 3.5.1

# %%
pip install mlflow==2.14.1
# Out:
# Collecting mlflow==2.14.1
#   Using cached mlflow-2.14.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: Flask<4 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (1.17.1)
# Collecting cachetools<6,>=5.0.0 (from mlflow==2.14.1)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: click<9,>=7.0 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (8.3.0)
# Requirement already satisfied: cloudpickle<4 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (3.1.1)
# Requirement already satisfied: docker<8,>=4.0.0 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (7.1.0)
# Collecting entrypoints<1 (from mlflow==2.14.1)
#   Using cached entrypoints-0.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (3.1.45)
# Requirement already satisfied: graphene<4 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (3.4.3)
# Collecting importlib-metadata!=4.7.0,<8,>=3.7.0 (from mlflow==2.14.1)
#   Using cached importlib_metadata-7.2.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting markdown<4,>=3.3 (from mlflow==2.14.1)
#   Downloading markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: matplotlib<4 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (3.10.7)
# Collecting numpy<2 (from mlflow==2.14.1)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (1.38.0)
# Collecting packaging<25 (from mlflow==2.14.1)
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas<3 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (2.3.3)
# Collecting protobuf<5,>=3.12.0 (from mlflow==2.14.1)
#   Using cached protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting pyarrow<16,>=4.0.0 (from mlflow==2.14.1)
#   Downloading pyarrow-15.0.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting pytz<2025 (from mlflow==2.14.1)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pyyaml<7,>=5.1 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (6.0.3)
# Collecting querystring-parser<2 (from mlflow==2.14.1)
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl.metadata (559 bytes)
# Requirement already satisfied: requests<3,>=2.17.3 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (2.32.5)
# Requirement already satisfied: scikit-learn<2 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (1.7.2)
# Requirement already satisfied: scipy<2 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (1.16.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (2.0.44)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (0.5.3)
# Requirement already satisfied: Jinja2<4,>=2.11 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from mlflow==2.14.1) (3.1.6)
# Collecting gunicorn<23 (from mlflow==2.14.1)
#   Using cached gunicorn-22.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: Mako in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow==2.14.1) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow==2.14.1) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from docker<8,>=4.0.0->mlflow==2.14.1) (2.5.0)
# Requirement already satisfied: blinker>=1.9.0 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from Flask<4->mlflow==2.14.1) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from Flask<4->mlflow==2.14.1) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from Flask<4->mlflow==2.14.1) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from Flask<4->mlflow==2.14.1) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow==2.14.1) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow==2.14.1) (5.0.2)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from graphene<4->mlflow==2.14.1) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from graphene<4->mlflow==2.14.1) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from graphene<4->mlflow==2.14.1) (2.9.0.post0)
# Requirement already satisfied: zipp>=0.5 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow==2.14.1) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.14.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.14.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.14.1) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.14.1) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.14.1) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.14.1) (3.2.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow==2.14.1) (0.59b0)
# Requirement already satisfied: tzdata>=2022.7 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from pandas<3->mlflow==2.14.1) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow==2.14.1) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow==2.14.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow==2.14.1) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow==2.14.1) (2025.10.5)
# Requirement already satisfied: joblib>=1.2.0 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from scikit-learn<2->mlflow==2.14.1) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from scikit-learn<2->mlflow==2.14.1) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /home/mohamad/miniconda3/envs/datalayer/lib/python3.11/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.14.1) (3.2.4)
# Using cached mlflow-2.14.1-py3-none-any.whl (25.8 MB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Using cached gunicorn-22.0.0-py3-none-any.whl (84 kB)
# Using cached importlib_metadata-7.2.1-py3-none-any.whl (25 kB)
# Downloading markdown-3.10-py3-none-any.whl (107 kB)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 211.0 kB/s  0:01:05 eta 0:00:010:04:05
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Using cached protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Downloading pyarrow-15.0.2-cp311-cp311-manylinux_2_28_x86_64.whl (38.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 230.3 kB/s  0:02:43 eta 0:00:010:00:06
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Installing collected packages: pytz, querystring-parser, protobuf, packaging, numpy, markdown, importlib-metadata, entrypoints, cachetools, pyarrow, gunicorn, mlflow
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.33.0
#     Uninstalling protobuf-6.33.0:
#       Successfully uninstalled protobuf-6.33.0
#   Attempting uninstall: packaging38;2;249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/12 [protobuf]
#     Found existing installation: packaging 25.0━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/12 [protobuf]
#     Uninstalling packaging-25.0:2;249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/12 [protobuf]
#       Successfully uninstalled packaging-25.0╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/12 [protobuf]
#   Attempting uninstall: numpy━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/12 [packaging]f]
#     Found existing installation: numpy 2.3.4━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/12 [packaging]
#     Uninstalling numpy-2.3.4:0m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/12 [packaging]
#       Successfully uninstalled numpy-2.3.4╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/12 [packaging]
#   Attempting uninstall: importlib-metadata;5;237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━  4/12 [numpy]
#     Found existing installation: importlib_metadata 8.7.0237m━━━━━━━━━━━━━━━━━━━━━━━━━━  4/12 [numpy]
#     Uninstalling importlib_metadata-8.7.0:37m╺━━━━━━━━━━━━━━━━━━━━━━━━━━  4/12 [numpy]
#       Successfully uninstalled importlib_metadata-8.7.05;237m━━━━━━━━━━━━━━━━━━━━━━━━━━  4/12 [numpy]
#   Attempting uninstall: cachetools━━━━━━━╺━━━━━━━━━━━━━━━━━━━  6/12 [importlib-metadata]
#     Found existing installation: cachetools 6.2.137m╺━━━━━━━━━━━━━━━━━━━  6/12 [importlib-metadata]
#     Uninstalling cachetools-6.2.1:━━━╺━━━━━━━━━━━━━━━━━━━  6/12 [importlib-metadata]
#       Successfully uninstalled cachetools-6.2.1;237m╺━━━━━━━━━━━━━━━━━━━  6/12 [importlib-metadata]
#   Attempting uninstall: pyarrow━━━━━━╺━━━━━━━━━━━━━━━━━━━  6/12 [importlib-metadata]
#     Found existing installation: pyarrow 21.0.0;237m╺━━━━━━━━━━━━━━━━━━━  6/12 [importlib-metadata]
#     Uninstalling pyarrow-21.0.0:━━━━━╺━━━━━━━━━━━━━━━━━━━  6/12 [importlib-metadata]
#       Successfully uninstalled pyarrow-21.0.0;5;237m╺━━━━━━━━━━━━━━━━━━━  6/12 [importlib-metadata]
#   Attempting uninstall: gunicorn━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━  9/12 [pyarrow]tadata]
#     Found existing installation: gunicorn 23.0.0━━━━━━╺━━━━━━ 10/12 [gunicorn]
#     Uninstalling gunicorn-23.0.0:━━━━━━━━━━━━━━━━━╺━━━━━━ 10/12 [gunicorn]
#       Successfully uninstalled gunicorn-23.0.0━━━━╺━━━━━━ 10/12 [gunicorn]
#   Attempting uninstall: mlflow━━━━━━━━━━━━━━━━━━━━╺━━━━━━ 10/12 [gunicorn]
#     Found existing installation: mlflow 3.5.1━━━━━╺━━━━━━ 10/12 [gunicorn]
#     Uninstalling mlflow-3.5.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━ 11/12 [mlflow]
#       Successfully uninstalled mlflow-3.5.1━━━━━━━━━━╸━━━ 11/12 [mlflow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/12 [mlflow]5;237m━━━ 11/12 [mlflow]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.8 which is incompatible.
# Successfully installed cachetools-5.5.2 entrypoints-0.4 gunicorn-22.0.0 importlib-metadata-7.2.1 markdown-3.10 mlflow-2.14.1 numpy-1.26.4 packaging-24.2 protobuf-4.25.8 pyarrow-15.0.2 pytz-2024.2 querystring-parser-1.2.4
# Note: you may need to restart the kernel to use updated packages.
