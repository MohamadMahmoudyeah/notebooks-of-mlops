# %%
print("somefgfdhthings")
# Out:
# somefgfdhthings

# %%
print("sfda")
# Out:
# sfda

# %%
afsda
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 afsda
#
# NameError: name 'afsda' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris

# --- Train a scikit-learn model ---
X, y = load_iris(return_X_y=True)
sklearn_model = RandomForestClassifier().fit(X, y)

my_custom_tags = {
    "tag": 0.98,
    "model_type": "RandomForest"
}
start_run("new_run")
register_model(sklearn_model, "MyModel", tags=my_custom_tags)
end_run()
# Out:
# --- [SDK] Finding notebook path to set experiment...
# --- [SDK] Automatically setting experiment to: 'path-16500d19-4e2b-4c19-8446-edcac2d07833' ---
# --- [SDK] Starting run: new_run (ID: b36b9987fc254459a70869c7447b1c11) ---
# Attempting to register model MyModel.
# Detected scikit-learn model.
# Registered model 'MyModel' already exists. Creating a new version of this model...
# 2025/11/16 19:27:09 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: MyModel, version 15
# --- [SDK] Manually ending run: new_run ---
# Created version '15' of model 'MyModel'.

# %%
my_model = load_model("MyModel", 4)
# Out:
# --- [SDK] Attempting to load model 'MyModel'...
# --- [SDK] Loading version 4...
# --- [SDK] Successfully loaded model from: models:/MyModel/4

# %%
my_custom_tags = {
    "tag": 121218,
    "model_type": "AModel"
}
start_run("MRUN")
register_model(my_model, "CloneMyModelV4", tags=my_custom_tags)
end_run()
# Out:
# --- [SDK] Finding notebook path to set experiment...
# --- [SDK] Automatically setting experiment to: 'path-16500d19-4e2b-4c19-8446-edcac2d07833' ---
# --- [SDK] Starting run: MRUN (ID: d5bd615915e246208c45e2bfd4002cb9) ---
# Attempting to register model CloneMyModelV4.
# Detected scikit-learn model.
# Successfully registered model 'CloneMyModelV4'.
# 2025/11/16 19:48:19 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: CloneMyModelV4, version 1
# --- [SDK] Manually ending run: MRUN ---
# Created version '1' of model 'CloneMyModelV4'.
